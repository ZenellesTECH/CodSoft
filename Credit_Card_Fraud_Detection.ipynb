# %% [markdown]
# <a href="https://colab.research.google.com/github/ZenellesTECH/CodSoft/blob/main/Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 5: Credit Card Fraud Detection
# Programmer: Jayeola Ayomide Mary
# Domain: Data Science
# Batch: June A59
# Aim: To bulid amachine learning model to identify fraudulent credit card transactions.

# %% [markdown]
# Importing the  Labraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
#loading the dataset to the pandas datsframe
data= pd.read_csv('/content/creditcard.csv')
data
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 0            0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1            0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2            1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3            1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4            2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...          ...       ...       ...       ...       ...       ...       ...
# 225830  144415.0  2.042317 -0.143495 -2.954711 -0.579241  2.610433  3.142249
# 225831  144416.0  1.966844 -0.845034 -0.107284 -1.487196 -1.204514 -0.599232
# 225832  144416.0  0.081639  0.619585 -1.592527 -1.516643  3.044799  3.289021
# 225833  144416.0 -0.434838  1.277109 -3.562713 -1.377520  3.088281  2.657429
# 225834  144416.0 -5.201061 -1.797970 -0.343040  1.980920  0.287586 -0.429028
#
# ...

# %%
df=pd.DataFrame(data)
df
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 0            0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1            0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2            1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3            1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4            2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...          ...       ...       ...       ...       ...       ...       ...
# 225830  144415.0  2.042317 -0.143495 -2.954711 -0.579241  2.610433  3.142249
# 225831  144416.0  1.966844 -0.845034 -0.107284 -1.487196 -1.204514 -0.599232
# 225832  144416.0  0.081639  0.619585 -1.592527 -1.516643  3.044799  3.289021
# 225833  144416.0 -0.434838  1.277109 -3.562713 -1.377520  3.088281  2.657429
# 225834  144416.0 -5.201061 -1.797970 -0.343040  1.980920  0.287586 -0.429028
#
# ...

# %%
#Checking for the missing values in each coloumn
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
#distributing of normal and fraudulent transactions
df['Class'].value_counts()
# Out:
# Class
# 0.0    225419
# 1.0       415
# Name: count, dtype: int64

# %% [markdown]
# Unbalanced Dataset
# 0==Normal transactions
# 1==Fraudulent transactions

# %%
#separating the data to be analysized
Normal=df[df.Class==0]
Fraud=df[df.Class==1]

# %%
print(Normal.shape)
print(Fraud.shape)
# Out:
# (225419, 31)
# (415, 31)

# %%
#Statistical measures of the data
Normal.Amount.describe()
Fraud.Amount.describe()
# Out:
# count     415.000000
# mean      124.653398
# std       256.043305
# min         0.000000
# 25%         1.000000
# 50%        12.310000
# 75%       106.725000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#compering the values
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    78478.303932 -0.060435 -0.020045  0.204692  0.037688 -0.059293
# 1.0    66934.766265 -5.385937  3.966763 -7.457503  4.664025 -3.779142
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.034347 -0.016559  0.003799  0.007351  ...  0.009627 -0.008041
# 1.0   -1.356134 -6.279493  0.656473 -2.698293  ...  0.381241  0.766231
#
#             V22       V23       V24       V25       V26       V27      V28  \
# Class
# 0.0   -0.024008 -0.010307  0.001281  0.039669  0.003145 -0.000076  0.00194
# 1.0    0.012771 -0.054751 -0.082825  0.047755  0.038529  0.199928  0.06061
#
#            Amount
# Class
# 0.0     90.744375
# 1.0    124.653398
#
# [2 rows x 30 columns]

# %% [markdown]
# Undersampling
# building a sample dataset with similar distribution of normal and fraudulent transactions

# %%
Normal_sample=Normal.sample(n=492)

# %% [markdown]
# Concatenating two dataframes

# %%
new_dataset=pd.concat([Normal_sample,Fraud],axis=0)
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 114327   73436.0  1.100730 -0.292767  0.044145  0.756014  0.172088  1.141196
# 95997    65558.0 -0.407669  0.954747  0.486546  1.382499  2.449851  4.497256
# 126847   78125.0 -2.668402  2.399521 -0.734099  0.308989  0.073635  0.348025
# 81096    58784.0 -8.300805  3.038417 -2.368696 -3.870221 -3.366378  3.119381
# 162287  114992.0 -0.068616 -0.183639 -0.787402 -1.020092  1.228766  4.549885
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 114327 -0.503293  0.418397  0.401503  ...  0.102619  0.103217 -0.301223
# 95997   0.305863  0.742228 -0.852223  ... -0.257352 -0.656985 -0.091925
# 126847 -0.162213  0.640123  0.412475  ...  0.202541  0.207965 -0.131943
# 81096  -6.544919 -9.299727  0.868151  ...  3.824882 -0.442203  1.371797
# 162287 -1.323151  1.818437  1.278267  ...  0.259832  0.736702  0.397848
#
# ...

# %%
new_dataset.tail()
new_dataset['Class'].value_counts()
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    78636.770325 -0.097052 -0.194373  0.212889  0.061066 -0.022302
# 1.0    66934.766265 -5.385937  3.966763 -7.457503  4.664025 -3.779142
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.010730  0.024859 -0.015616 -0.031234  ... -0.032722 -0.033951
# 1.0   -1.356134 -6.279493  0.656473 -2.698293  ...  0.381241  0.766231
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.026247 -0.007269 -0.015800  0.044352 -0.031908 -0.005462 -0.001402
# 1.0    0.012771 -0.054751 -0.082825  0.047755  0.038529  0.199928  0.060610
#
#            Amount
# Class
# 0.0     95.182093
# 1.0    124.653398
#
# [2 rows x 30 columns]

# %%
#spliting the data into target and features
x=new_dataset.drop(columns='Class',axis=1)
y=new_dataset['Class']

# %%
print(x)
print(y)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 114327   73436.0  1.100730 -0.292767  0.044145  0.756014  0.172088  1.141196
# 95997    65558.0 -0.407669  0.954747  0.486546  1.382499  2.449851  4.497256
# 126847   78125.0 -2.668402  2.399521 -0.734099  0.308989  0.073635  0.348025
# 81096    58784.0 -8.300805  3.038417 -2.368696 -3.870221 -3.366378  3.119381
# 162287  114992.0 -0.068616 -0.183639 -0.787402 -1.020092  1.228766  4.549885
# ...          ...       ...       ...       ...       ...       ...       ...
# 222419  142961.0  0.457845  1.373769 -0.488926  2.805351  1.777386  0.100492
# 223366  143354.0  1.118331  2.074439 -3.837518  5.448060  0.071816 -1.020509
# 223572  143434.0 -2.729482  3.312495 -4.242710  5.036985 -0.376561 -1.532462
# 223578  143438.0 -5.256434  0.364541 -5.412085  2.400031  0.697301 -1.998755
# 223618  143456.0 -2.006582  3.676577 -5.463811  7.232058 -1.627859 -0.996755
#
# ...

# %%
#splitting the data into training and testing data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (907, 30) (725, 30) (182, 30)

# %% [markdown]
# Model training,
# Logistic Regression

# %%
#training the Logistic Regression with training data
Lr=LogisticRegression()
Lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaluation
# Accuracy Score

# %%
#accuracy on training data
x_train_prediction=Lr.predict(x_train)
training_data_accuracy=accuracy_score(x_train_prediction,y_train)
print(training_data_accuracy)
# Out:
# 0.9489655172413793

# %%
#accuracy on testing data
x_test_prediction=Lr.predict(x_test)
testing_data_accuracy=accuracy_score(x_test_prediction,y_test)
print(testing_data_accuracy)
# Out:
# 0.9120879120879121
